# %%
import numpy as np
from scipy.integrate import ode
from lorenz96 import Lorenz96
from dataGenerator import DataGenerator

# %% [markdown]
# ### Q1 (b-1)

# %%
mean = 0
std = 1.0
nGrid = 100
force = 8
nTimeStep = 500
dt = 0.01
spinUpTimeStep = 200

# %%
initPerturb = np.random.normal(mean, std, size=nGrid)
time = np.arange(0, (nTimeStep)*dt, dt)
x = np.arange(0, nGrid)


stateGenerator = DataGenerator(nTimeStep=nTimeStep+spinUpTimeStep, dt=dt)
stateGenerator.setupLorenz96(initPerturb, force=force)
truthState = stateGenerator.getSeriesTruth()
# Out:
# <scipy.integrate._ode.ode object at 0x7fc128229d30>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# Current TimeStep: 500 | Time: 5.0
# Current TimeStep: 550 | Time: 5.5
# Current TimeStep: 600 | Time: 6.0
# Current TimeStep: 650 | Time: 6.5

# %%
print(truthState.shape)
# Out:
# (700, 100)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 8))
plt.pcolormesh(x, np.arange(0, truthState.shape[0]*dt, dt), truthState, shading="nearest")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("X", fontsize=15)
plt.ylabel("Time", fontsize=15)
plt.show()

# %% [markdown]
# ### Q1 (b-2)

# %%
# take t=2 as the spinned up state
initState = truthState[spinUpTimeStep:, :][0]
plt.plot(initState)
plt.show()

# %%
numEnsemble = 50
ensemMemResults = []
for i in range(numEnsemble):
    print(f"========== Mem {i} ==========")
    initPerturb = initState + np.random.normal(mean, std, size=nGrid)
    stateGenerator = DataGenerator(nTimeStep=nTimeStep, dt=dt)
    stateGenerator.setupLorenz96(initPerturb, force=force)
    ensemState = stateGenerator.getSeriesTruth()
    #np.save(f"./dat_F8/lorenz96-{i:06d}.npy", ensemState)
    ensemMemResults.append(ensemState)
# Out:
# ========== Mem 0 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839cb20>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 1 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839cb80>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 2 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839c6d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 3 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839cb50>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 4 ==========
# <scipy.integrate._ode.ode object at 0x7fc1283b2f10>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 5 ==========
# <scipy.integrate._ode.ode object at 0x7fc1283b2f10>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 6 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c40d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 7 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c41f0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 8 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c43a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 9 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c44f0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 10 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4640>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 11 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4790>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 12 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c49a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 13 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4880>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 14 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4790>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 15 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4d30>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 16 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4f10>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 17 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c4fd0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 18 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c50d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 19 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5100>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 20 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c53d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 21 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5490>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 22 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5700>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 23 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c56a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 24 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c59d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 25 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5a60>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 26 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5b50>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 27 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5df0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 28 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5a60>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 29 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c5df0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 30 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9220>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 31 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9130>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 32 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9430>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 33 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9580>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 34 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9730>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 35 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9910>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 36 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c99a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 37 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9af0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 38 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9c70>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 39 ==========
# <scipy.integrate._ode.ode object at 0x7fc1283b2e80>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 40 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839c9a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 41 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839c9a0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 42 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839c6d0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 43 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839cb20>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 44 ==========
# <scipy.integrate._ode.ode object at 0x7fc12839caf0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 45 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9b80>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 46 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9ac0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 47 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9880>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 48 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9ac0>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5
# ========== Mem 49 ==========
# <scipy.integrate._ode.ode object at 0x7fc1284c9970>
# Current TimeStep: 050 | Time: 0.5
# Current TimeStep: 100 | Time: 1.0
# Current TimeStep: 150 | Time: 1.5
# Current TimeStep: 200 | Time: 2.0
# Current TimeStep: 250 | Time: 2.5
# Current TimeStep: 300 | Time: 3.0
# Current TimeStep: 350 | Time: 3.5
# Current TimeStep: 400 | Time: 4.0
# Current TimeStep: 450 | Time: 4.5

# %%
def rmse(truth, mem):
    return (np.mean((truth-mem)**2))**(1/2)

# %%
truthState = truthState[spinUpTimeStep:, :]

# %%
rmseRecord = np.zeros(shape=(len(time), numEnsemble))
for i in range(nTimeStep):
    for memIdx, mem in enumerate(ensemMemResults):
        rmseRecord[i, memIdx] = rmse(truthState[i], mem[i])

# %%
meanError = rmseRecord.mean(axis=1)
plt.figure(figsize=(15, 8))
plt.grid(True)
plt.plot(time, np.log10(meanError**2))
#plt.yscale("log")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Time", fontsize=15)
plt.ylabel(r"Log($E^2$)", fontsize=15)
plt.show()

# %%
doubleError = 10**(np.log10(rmseRecord.mean(axis=1)[0]) + np.log10(2))
print(time[np.argmin(np.abs(meanError-doubleError))])
# Out:
# 0.38
